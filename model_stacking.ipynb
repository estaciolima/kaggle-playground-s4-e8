# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import matthews_corrcoef
import optuna
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import VarianceThreshold
import xgboost as xgb
import lightgbm as lgb
import catboost as cb
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/kaggle/input/playground-series-s4e8/train.csv', index_col='id')
df.drop_duplicates(inplace=True)
X = df.drop('class', axis=1)
y = df['class']
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
num_var = X.select_dtypes(['float64']).columns.to_list()
cat_var = X.select_dtypes(['object']).columns.to_list()
transformer = ColumnTransformer([('num', StandardScaler(), num_var),
                                 ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_var)])

X_trans = transformer.fit_transform(X)

num_cols = transformer.named_transformers_['num'].get_feature_names_out().tolist()
cat_cols = transformer.named_transformers_['cat'].get_feature_names_out().tolist()
columns = num_cols + cat_cols

X_trans = pd.DataFrame.sparse.from_spmatrix(X_trans, columns=columns)
y_trans = y.map({'p': 1, 'e': 0})

# %%
sel = VarianceThreshold(threshold=0.001)
X_sel = sel.fit_transform(X_trans)
X_sel = X_sel.toarray()

# %%
models = {}

xgb_params = {'eta': 0.14125997609617025,
 'max_depth': 20,
 'lambda': 0.9674532237426338,
 'min_child_weight': 4.082841046413778,
 'subsample': 0.8776652508409101,
 'colsample_bytree': 0.7417850753962157}

models['xgb'] = xgb.XGBClassifier(**xgb_params)

lgbm_params = {'num_leaves': 140,
 'learning_rate': 0.09154835441455036,
 'feature_fraction': 0.5806836555634359,
 'bagging_fraction': 0.9884282473485232,
 'bagging_freq': 7,
 'min_child_samples': 98,
 'verbose': -1}

models['lgb'] = lgb.LGBMClassifier(**lgbm_params)

dart_params = {'num_leaves': 236,
 'learning_rate': 0.17745389398567907,
 'feature_fraction': 0.5590877395748017,
 'bagging_fraction': 0.9950711489582625,
 'bagging_freq': 1,
 'min_child_samples': 85,
 'verbose': -1}

models['dart'] = lgb.LGBMClassifier(**dart_params)

catboost_params = {'iterations': 159,
                   'learning_rate': 0.17379868130781356,
                   'depth': 11,
                   'border_count': 80,
                   'verbose': 0}

models['catboost'] = cb.CatBoostClassifier(**catboost_params)

# %%
oof_preds = {}
kf = KFold(n_splits=5, shuffle=True, random_state=2)

def get_oof_predictions(X, y, model):
    for i, (train_index, test_index) in enumerate(kf.split(X)):
        X_train = X[train_index]
        y_train = y[train_index]
        X_test = X[test_index]
        global y_oof
        y_oof = y[test_index]

        print(f'Fold {i}')
        models[model].fit(X_train, y_train)
        oof_pred = models[model].predict(X_test)
        mcc = matthews_corrcoef(y_oof, oof_pred)
        print(f'MCC: {mcc}')

        break
    
    return oof_pred

for model in models:
    print(f'Model: {model}')
    oof_preds[model] = get_oof_predictions(X_sel, y_trans, model)

oof_preds['target'] = y_oof
# Out:
# Fold 0
# Fold 0
# Fold 0
# [LightGBM] [Warning] feature_fraction is set=0.5590877395748017, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5590877395748017
# [LightGBM] [Warning] bagging_fraction is set=0.9950711489582625, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9950711489582625
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.5590877395748017, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5590877395748017
# [LightGBM] [Warning] bagging_fraction is set=0.9950711489582625, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9950711489582625
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 43797, number of negative: 36203
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004656 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1003
# [LightGBM] [Info] Number of data points in the train set: 80000, number of used features: 122
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.547462 -> initscore=0.190423
# [LightGBM] [Info] Start training from score 0.190423
# [LightGBM] [Warning] feature_fraction is set=0.5590877395748017, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5590877395748017
# [LightGBM] [Warning] bagging_fraction is set=0.9950711489582625, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9950711489582625
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Fold 0
# 0:	learn: 0.4862876	total: 110ms	remaining: 17.4s
# 1:	learn: 0.3916988	total: 161ms	remaining: 12.6s
# 2:	learn: 0.3251627	total: 205ms	remaining: 10.6s
# 3:	learn: 0.2706753	total: 250ms	remaining: 9.67s
# 4:	learn: 0.2261945	total: 290ms	remaining: 8.93s
# 5:	learn: 0.1900897	total: 366ms	remaining: 9.33s
# 6:	learn: 0.1640041	total: 449ms	remaining: 9.76s
# 7:	learn: 0.1438769	total: 517ms	remaining: 9.76s
# 8:	learn: 0.1302906	total: 567ms	remaining: 9.46s
# 9:	learn: 0.1187435	total: 614ms	remaining: 9.14s
# 10:	learn: 0.1083720	total: 652ms	remaining: 8.77s
# 11:	learn: 0.1012760	total: 694ms	remaining: 8.5s
# 12:	learn: 0.0944685	total: 744ms	remaining: 8.36s
# 13:	learn: 0.0857126	total: 788ms	remaining: 8.16s
# 14:	learn: 0.0811587	total: 832ms	remaining: 7.99s
# 15:	learn: 0.0771079	total: 870ms	remaining: 7.77s
# 16:	learn: 0.0735936	total: 905ms	remaining: 7.56s
# 17:	learn: 0.0690823	total: 940ms	remaining: 7.36s
# 18:	learn: 0.0660354	total: 972ms	remaining: 7.16s
# 19:	learn: 0.0632258	total: 1.01s	remaining: 7.02s
# 20:	learn: 0.0603186	total: 1.05s	remaining: 6.89s
# 21:	learn: 0.0585685	total: 1.09s	remaining: 6.78s
# 22:	learn: 0.0562751	total: 1.13s	remaining: 6.65s
# 23:	learn: 0.0546435	total: 1.19s	remaining: 6.68s
# 24:	learn: 0.0535241	total: 1.23s	remaining: 6.6s
# 25:	learn: 0.0514112	total: 1.27s	remaining: 6.52s
# 26:	learn: 0.0502054	total: 1.32s	remaining: 6.43s
# 27:	learn: 0.0491492	total: 1.35s	remaining: 6.33s
# 28:	learn: 0.0483492	total: 1.39s	remaining: 6.22s
# 29:	learn: 0.0473712	total: 1.43s	remaining: 6.13s
# 30:	learn: 0.0464895	total: 1.47s	remaining: 6.06s
# 31:	learn: 0.0457684	total: 1.5s	remaining: 5.97s
# 32:	learn: 0.0450931	total: 1.54s	remaining: 5.9s
# 33:	learn: 0.0445531	total: 1.58s	remaining: 5.81s
# 34:	learn: 0.0437304	total: 1.62s	remaining: 5.73s
# 35:	learn: 0.0428224	total: 1.65s	remaining: 5.65s
# 36:	learn: 0.0423668	total: 1.69s	remaining: 5.58s
# 37:	learn: 0.0419136	total: 1.73s	remaining: 5.52s
# 38:	learn: 0.0413843	total: 1.76s	remaining: 5.43s
# 39:	learn: 0.0410319	total: 1.8s	remaining: 5.34s
# 40:	learn: 0.0408067	total: 1.83s	remaining: 5.27s
# 41:	learn: 0.0404135	total: 1.86s	remaining: 5.18s
# 42:	learn: 0.0398616	total: 1.89s	remaining: 5.1s
# 43:	learn: 0.0394527	total: 1.94s	remaining: 5.06s
# 44:	learn: 0.0391102	total: 1.97s	remaining: 4.99s
# 45:	learn: 0.0387547	total: 2s	remaining: 4.92s
# 46:	learn: 0.0383901	total: 2.04s	remaining: 4.86s
# 47:	learn: 0.0379874	total: 2.07s	remaining: 4.79s
# 48:	learn: 0.0377736	total: 2.11s	remaining: 4.74s
# 49:	learn: 0.0372103	total: 2.15s	remaining: 4.69s
# 50:	learn: 0.0368484	total: 2.19s	remaining: 4.63s
# 51:	learn: 0.0363630	total: 2.22s	remaining: 4.57s
# 52:	learn: 0.0360675	total: 2.25s	remaining: 4.5s
# 53:	learn: 0.0358267	total: 2.29s	remaining: 4.45s
# 54:	learn: 0.0357447	total: 2.3s	remaining: 4.36s
# 55:	learn: 0.0354692	total: 2.35s	remaining: 4.32s
# 56:	learn: 0.0351040	total: 2.41s	remaining: 4.31s
# 57:	learn: 0.0348077	total: 2.44s	remaining: 4.26s
# 58:	learn: 0.0344735	total: 2.48s	remaining: 4.2s
# 59:	learn: 0.0343111	total: 2.5s	remaining: 4.13s
# 60:	learn: 0.0341208	total: 2.54s	remaining: 4.08s
# 61:	learn: 0.0340121	total: 2.58s	remaining: 4.03s
# 62:	learn: 0.0338160	total: 2.62s	remaining: 3.99s
# 63:	learn: 0.0336777	total: 2.65s	remaining: 3.93s
# 64:	learn: 0.0334902	total: 2.68s	remaining: 3.88s
# 65:	learn: 0.0332002	total: 2.72s	remaining: 3.83s
# 66:	learn: 0.0329854	total: 2.75s	remaining: 3.77s
# 67:	learn: 0.0327866	total: 2.78s	remaining: 3.73s
# 68:	learn: 0.0325238	total: 2.82s	remaining: 3.68s
# 69:	learn: 0.0323751	total: 2.86s	remaining: 3.64s
# 70:	learn: 0.0322132	total: 2.9s	remaining: 3.6s
# 71:	learn: 0.0319288	total: 2.94s	remaining: 3.55s
# 72:	learn: 0.0317772	total: 2.97s	remaining: 3.5s
# 73:	learn: 0.0314791	total: 3.01s	remaining: 3.46s
# 74:	learn: 0.0313036	total: 3.05s	remaining: 3.41s
# 75:	learn: 0.0312170	total: 3.08s	remaining: 3.36s
# 76:	learn: 0.0310940	total: 3.11s	remaining: 3.31s
# 77:	learn: 0.0310855	total: 3.11s	remaining: 3.23s
# 78:	learn: 0.0309548	total: 3.15s	remaining: 3.19s
# 79:	learn: 0.0307414	total: 3.19s	remaining: 3.15s
# 80:	learn: 0.0306954	total: 3.23s	remaining: 3.11s
# 81:	learn: 0.0306034	total: 3.27s	remaining: 3.07s
# 82:	learn: 0.0305372	total: 3.31s	remaining: 3.03s
# 83:	learn: 0.0304294	total: 3.34s	remaining: 2.98s
# 84:	learn: 0.0304044	total: 3.38s	remaining: 2.94s
# 85:	learn: 0.0303177	total: 3.42s	remaining: 2.9s
# 86:	learn: 0.0301708	total: 3.45s	remaining: 2.86s
# 87:	learn: 0.0301017	total: 3.49s	remaining: 2.81s
# 88:	learn: 0.0299229	total: 3.52s	remaining: 2.77s
# 89:	learn: 0.0299015	total: 3.56s	remaining: 2.73s
# 90:	learn: 0.0297399	total: 3.59s	remaining: 2.68s
# 91:	learn: 0.0295837	total: 3.62s	remaining: 2.64s
# 92:	learn: 0.0294618	total: 3.66s	remaining: 2.59s
# 93:	learn: 0.0293636	total: 3.7s	remaining: 2.56s
# 94:	learn: 0.0293106	total: 3.73s	remaining: 2.51s
# 95:	learn: 0.0292323	total: 3.77s	remaining: 2.47s
# 96:	learn: 0.0290034	total: 3.8s	remaining: 2.43s
# 97:	learn: 0.0288501	total: 3.83s	remaining: 2.39s
# 98:	learn: 0.0287892	total: 3.87s	remaining: 2.35s
# 99:	learn: 0.0287613	total: 3.91s	remaining: 2.31s
# 100:	learn: 0.0286091	total: 3.94s	remaining: 2.26s
# 101:	learn: 0.0283662	total: 3.98s	remaining: 2.22s
# 102:	learn: 0.0282581	total: 4.02s	remaining: 2.18s
# 103:	learn: 0.0281686	total: 4.05s	remaining: 2.14s
# 104:	learn: 0.0280464	total: 4.09s	remaining: 2.1s
# 105:	learn: 0.0279297	total: 4.13s	remaining: 2.06s
# 106:	learn: 0.0277897	total: 4.16s	remaining: 2.02s
# 107:	learn: 0.0277100	total: 4.2s	remaining: 1.98s
# 108:	learn: 0.0276004	total: 4.23s	remaining: 1.94s
# 109:	learn: 0.0275036	total: 4.28s	remaining: 1.9s
# 110:	learn: 0.0272796	total: 4.31s	remaining: 1.86s
# 111:	learn: 0.0271221	total: 4.34s	remaining: 1.82s
# 112:	learn: 0.0270070	total: 4.38s	remaining: 1.78s
# 113:	learn: 0.0269596	total: 4.41s	remaining: 1.74s
# 114:	learn: 0.0268429	total: 4.44s	remaining: 1.7s
# 115:	learn: 0.0267264	total: 4.47s	remaining: 1.66s
# 116:	learn: 0.0266191	total: 4.5s	remaining: 1.62s
# 117:	learn: 0.0265226	total: 4.55s	remaining: 1.58s
# 118:	learn: 0.0263616	total: 4.59s	remaining: 1.54s
# 119:	learn: 0.0262825	total: 4.62s	remaining: 1.5s
# 120:	learn: 0.0261096	total: 4.66s	remaining: 1.46s
# 121:	learn: 0.0259159	total: 4.7s	remaining: 1.42s
# 122:	learn: 0.0257818	total: 4.73s	remaining: 1.38s
# 123:	learn: 0.0257309	total: 4.76s	remaining: 1.34s
# 124:	learn: 0.0256483	total: 4.8s	remaining: 1.3s
# 125:	learn: 0.0255787	total: 4.83s	remaining: 1.26s
# 126:	learn: 0.0255163	total: 4.86s	remaining: 1.23s
# 127:	learn: 0.0253465	total: 4.89s	remaining: 1.19s
# 128:	learn: 0.0253062	total: 4.93s	remaining: 1.15s
# 129:	learn: 0.0252523	total: 4.96s	remaining: 1.1s
# 130:	learn: 0.0252267	total: 5s	remaining: 1.07s
# 131:	learn: 0.0250666	total: 5.04s	remaining: 1.03s
# 132:	learn: 0.0250140	total: 5.07s	remaining: 992ms
# 133:	learn: 0.0249589	total: 5.11s	remaining: 954ms
# 134:	learn: 0.0248541	total: 5.14s	remaining: 914ms
# 135:	learn: 0.0247987	total: 5.18s	remaining: 875ms
# 136:	learn: 0.0247165	total: 5.21s	remaining: 836ms
# 137:	learn: 0.0246436	total: 5.24s	remaining: 797ms
# 138:	learn: 0.0245986	total: 5.27s	remaining: 759ms
# 139:	learn: 0.0244880	total: 5.3s	remaining: 720ms
# 140:	learn: 0.0243400	total: 5.34s	remaining: 682ms
# 141:	learn: 0.0241877	total: 5.37s	remaining: 643ms
# 142:	learn: 0.0241083	total: 5.41s	remaining: 605ms
# 143:	learn: 0.0240509	total: 5.45s	remaining: 568ms
# 144:	learn: 0.0239254	total: 5.49s	remaining: 530ms
# 145:	learn: 0.0238039	total: 5.52s	remaining: 492ms
# 146:	learn: 0.0236831	total: 5.56s	remaining: 454ms
# 147:	learn: 0.0235946	total: 5.59s	remaining: 415ms
# 148:	learn: 0.0235545	total: 5.62s	remaining: 377ms
# 149:	learn: 0.0235209	total: 5.65s	remaining: 339ms
# 150:	learn: 0.0234916	total: 5.69s	remaining: 301ms
# 151:	learn: 0.0233987	total: 5.72s	remaining: 264ms
# 152:	learn: 0.0233265	total: 5.76s	remaining: 226ms
# 153:	learn: 0.0232503	total: 5.8s	remaining: 188ms
# 154:	learn: 0.0231209	total: 5.85s	remaining: 151ms
# 155:	learn: 0.0230550	total: 5.89s	remaining: 113ms
# 156:	learn: 0.0229660	total: 5.92s	remaining: 75.5ms
# 157:	learn: 0.0229250	total: 5.96s	remaining: 37.7ms
# 158:	learn: 0.0228651	total: 5.99s	remaining: 0us

# %%
df_stack = pd.DataFrame(oof_preds)
df_stack.head()
# Out:
# {'xgb': array([0, 0, 0, ..., 1, 1, 0]),
#  'lgb': array([0, 1, 0, ..., 1, 1, 0]),
#  'dart': array([0, 1, 0, ..., 1, 1, 0]),
#  'catboost': array([0, 0, 0, ..., 1, 1, 0]),
#  'target': id
#  4        0
#  9        0
#  10       0
#  14       1
#  17       1
#          ..
#  99966    0
#  99967    1
#  99972    1
#  99981    1
#  99988    0
#  Name: class, Length: 20000, dtype: int64}

# %%
lr = LogisticRegression()
X_stack = df_stack.drop('target', axis=1)
y_stack = df_stack['target']
lr.fit(X_stack, y_stack)
# Out:
#     xgb  lgb  dart  catboost  target
# id
# 4     0    0     0         0       0
# 9     0    1     1         0       0
# 10    0    0     0         0       0
# 14    1    1     1         1       1
# 17    1    1     1         1       1

# %%
lr.coef_
# Out:
# LogisticRegression()

# %%
# load test dataset
df_test = pd.read_csv('/kaggle/input/playground-series-s4e8/test.csv', index_col='id')

# preprocess
X_test_trans = transformer.transform(df_test)
X_test_trans = pd.DataFrame.sparse.from_spmatrix(X_test_trans, columns=columns)
X_test_sel = sel.transform(X_test_trans).toarray()

# make predictions
test_preds = {}

for model in models:
    print(f'Predict with model: {model}')
    test_preds[model] = models[model].predict(X_test_sel)
    
df_test_stack = pd.DataFrame(test_preds)

lr_pred = lr.predict(df_test_stack)
# Out:
# 0.9817050911597321

# %%
lr_pred = list(map(lambda x: 'p' if x==1 else 'e', lr_pred))
submission = pd.DataFrame({'id': df_test.index,
                          'class': lr_pred})
submission.head()

# %%
submission.to_csv('submission.csv', index=False)
